# %% [markdown]
# # 4. Testing, Debugging, and Integrated Challenges
#
# This notebook contains the final 25 exercises, focused on testing, debugging, and mixed end-to-end practice tasks.

# %% [markdown]
# ## 1. Unit Testing and Mocking
#
# 1. Write a `unittest.TestCase` for a function that adds VAT to a price.
# 2. Add a test that checks a function raises `ValueError` for invalid input.
# 3. Use `setUp()` to prepare a shared object for multiple tests.
# 4. Build a small `TestSuite` that combines two test classes.
# 5. Use `subTest()` to test multiple values with one test method.
# 6. Create a `Mock` object and verify that one of its methods was called once.
# 7. Patch a dependency such as `requests.get` or another helper function in a small example.

# %% [markdown]
# ## 2. Pytest and Debugging Basics
#
# 8. Write a simple pytest-style test function with one assertion.
# 9. Write a pytest-style test that checks for an exception.
# 10. Add a temporary-file test using `tmp_path` if pytest is available.
# 11. Read a traceback from a failing function and identify the exception type.
# 12. Use `print()` debugging to inspect a wrong intermediate value.
# 13. Use `type()` and `dir()` to inspect an unfamiliar object.
# 14. Create a short example where an `IndexError` occurs and then fix it.
# 15. Create a short example where a `KeyError` occurs and then fix it.

# %% [markdown]
# ## 3. Integrated Challenges
#
# 16. Write a function that reads names from a file and returns them in title case.
# 17. Write tests for the function from exercise 16.
# 18. Create a class that stores product information and can export itself as a dictionary.
# 19. Serialize a list of those product dictionaries to JSON.
# 20. Read the JSON data back and compute the average product price.
# 21. Write a decorator that logs every call to the average-price function.
# 22. Debug a function that mixes strings and numbers in a calculation.
# 23. Build a mini report that combines list processing, dictionaries, and functions.
# 24. Write tests for one part of that mini report.
# 25. Refactor one earlier solution to improve readability, naming, or error handling.
