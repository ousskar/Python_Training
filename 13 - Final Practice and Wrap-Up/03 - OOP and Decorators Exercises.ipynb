# %% [markdown]
# # 3. OOP and Decorators Exercises
#
# This notebook contains 25 exercises covering classes, inheritance, dataclasses, lambda functions, higher-order functions, and decorators.

# %% [markdown]
# ## 1. Classes and Objects
#
# 1. Create a `Car` class with `brand` and `speed` attributes.
# 2. Add a method to the `Car` class that prints a short description of the car.
# 3. Create a `BankAccount` class with `deposit()` and `withdraw()` methods.
# 4. Add validation so the account balance cannot go below zero.
# 5. Create a `Student` class with a method that returns whether the student passed based on a grade.
# 6. Add a `__str__()` method to one of your classes.
# 7. Add a property that computes a derived value, such as `is_overdrawn` or `is_fast`.

# %% [markdown]
# ## 2. Inheritance and Dataclasses
#
# 8. Create a `Person` base class and an `Employee` child class.
# 9. Override a method in the child class and also call the parent method with `super()`.
# 10. Create an abstract-style design where different animal classes each implement their own `sound()` behavior.
# 11. Rewrite a simple data-holder class as a dataclass.
# 12. Add default values to a dataclass field.
# 13. Add a validation step with `__post_init__()`.
# 14. Create a frozen dataclass and observe what happens if you try to modify it.

# %% [markdown]
# ## 3. Higher-Order Functions and Lambda
#
# 15. Use `lambda` with `sorted()` to sort a list of tuples by the second value.
# 16. Use `map()` to double each number in a list.
# 17. Use `filter()` to keep only names longer than four characters.
# 18. Write a function that accepts another function as an argument and applies it to each item in a list.
# 19. Write a closure that remembers a multiplier and returns a function that multiplies by it.

# %% [markdown]
# ## 4. Decorators
#
# 20. Write a decorator that prints a message before a function runs.
# 21. Write a decorator that measures how long a function takes to run.
# 22. Write a decorator that logs a function's arguments.
# 23. Use `functools.wraps` in one of your decorators.
# 24. Stack two decorators on the same function and observe the order of execution.
# 25. Write a decorator that blocks execution when a condition is false, such as a missing permission flag.
