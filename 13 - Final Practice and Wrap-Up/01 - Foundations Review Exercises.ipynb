# %% [markdown]
# # 1. Foundations Review Exercises
#
# This notebook contains 25 short exercises covering Python basics, data types, iterables, indexing, slicing, and flow control.
#
# Work through them in order. Write your code in new code cells under each section or under each individual exercise.

# %% [markdown]
# ## 1. Variables and Data Types
#
# 1. Create variables to store your name, age, and whether you are currently learning Python.
# 2. Convert the string `'42'` into an integer and multiply it by `2`.
# 3. Create a list with five numbers and print the largest value.
# 4. Create a tuple with three city names and print the second city.
# 5. Create a dictionary for a book with keys `title`, `author`, and `year`, then print the author.
# 6. Create a set from the list `[1, 2, 2, 3, 4, 4, 5]` and print the result.
# 7. Check the type of each of these values: `3.14`, `True`, `'hello'`, and `[1, 2]`.
# 8. Swap the values of two variables without using a third variable.

# %% [markdown]
# ## 2. Strings, Indexing, and Slicing
#
# 9. Store the word `Programming` in a variable and print its first and last characters.
# 10. Slice the first five characters from `Programming`.
# 11. Slice every second character from the string `abcdefghij`.
# 12. Reverse the string `Python` using slicing.
# 13. Count how many times the letter `a` appears in `banana`.
# 14. Convert `hello world` to title case.
# 15. Split the sentence `Python is fun to learn` into a list of words.
# 16. Join the list `['read', 'write', 'code']` into one string separated by ` - `.

# %% [markdown]
# ## 3. Iterables and Loops
#
# 17. Loop through a list of numbers and print only the even values.
# 18. Use `enumerate()` to print both the index and value for `['red', 'green', 'blue']`.
# 19. Use `zip()` to combine names and scores from two separate lists.
# 20. Create an iterator from a list and print the first two values using `next()`.
# 21. Write a loop that sums all numbers from `1` to `10`.
# 22. Build a list of squares from `1` to `8` using a `for` loop.
# 23. Rewrite the previous exercise using a list comprehension.

# %% [markdown]
# ## 4. Flow Control
#
# 24. Write an `if/elif/else` block that prints whether a number is positive, negative, or zero.
# 25. Write a loop that asks a user for input until they type `quit`. If you are working offline in a notebook, simulate this with a predefined list of inputs.
