# %% [markdown]
# # 2. Functions and Files Exercises
#
# This notebook contains 25 exercises focused on functions, scope, arguments, type hints, file handling, CSV, JSON, and modules.

# %% [markdown]
# ## 1. Functions Basics
#
# 1. Write a function `greet(name)` that returns a greeting message.
# 2. Write a function `square(number)` that returns the square of a number.
# 3. Write a function `is_even(number)` that returns `True` for even numbers and `False` otherwise.
# 4. Write a function `area_rectangle(width, height)`.
# 5. Write a function `full_name(first, last)` that returns a formatted full name.
# 6. Write a function with a default parameter for a country, such as `describe_person(name, country='Unknown')`.
# 7. Write a function that accepts a variable number of positional arguments and returns their sum.
# 8. Write a function that accepts keyword arguments and prints each key-value pair.

# %% [markdown]
# ## 2. Scope and Type Hints
#
# 9. Create a global variable and a function that reads it.
# 10. Create a function that defines a local variable with the same name as a global variable and compare the outputs.
# 11. Write a function `multiply(a: int, b: int) -> int`.
# 12. Write a function `average(values: list[float]) -> float`.
# 13. Write a function that returns `None` when given an empty list and a number otherwise.
# 14. Refactor a small function you already wrote by adding type hints to its parameters and return value.

# %% [markdown]
# ## 3. File Handling
#
# 15. Write text to a file named `practice.txt`.
# 16. Read the contents of `practice.txt` back into Python and print them.
# 17. Append a new line to `practice.txt`.
# 18. Count how many lines are in a text file.
# 19. Write a function that safely reads a file and handles `FileNotFoundError`.
# 20. Use `Path` from `pathlib` to build a file path and check whether it exists.

# %% [markdown]
# ## 4. CSV, JSON, and Modules
#
# 21. Read a CSV file and print each row.
# 22. Count how many rows in a CSV file contain a missing value.
# 23. Save a Python dictionary to a JSON file.
# 24. Read the JSON file back and print one field.
# 25. Create a small module with one helper function and import it into another file or notebook cell.
